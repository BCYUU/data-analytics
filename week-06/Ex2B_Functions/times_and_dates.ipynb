# %% [markdown]
# this is Lab 2 of Exercise 2.B, working
# with datetime functions

# %%
import datetime

# %% [markdown]
# # Today

# %%
today = datetime.datetime.now()
print(today)
# Out:
# 2026-05-13 23:10:43.007187

# %%
print(today.strftime("%A, %m, %Y"))
# Out:
# Wednesday, 05, 2026

# %% [markdown]
# # My birthday

# %%
birthday = datetime.date(2002,5,12)
print("the birthday is")
print(birthday.strftime("%m, %d, %Y "))
# Out:
# the birthday is
# 05, 12, 2002

# %% [markdown]
# no it isnt

# %% [markdown]
# # Next 90 Days

# %%
ninety_d = today + datetime.timedelta(days=90)

# %%
print(f" 90 days from now is {ninety_d.strftime('%m, %d, %Y ')}")
# Out:
#  90 days from now is 08, 11, 2026

# %% [markdown]
# # Time for Dinner

# %%
dinnerTime = datetime.time(2,22,22,222222)

print(f"ahahaaha lets meet for dinner at exactly   {dinnerTime.strftime('%H:%M:%S')}") # not my finest work
# Out:
# ahahaaha lets meet for dinner at exactly         02:22:22
